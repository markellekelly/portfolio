# %% [markdown]
# # Feature engineering

# %% [markdown]
# An agglomeration of several feature engineering notebooks used for the project.

# %%
import pandas as pd
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
import datetime
import numpy as np

# %% [markdown]
# ## 1. Merge with demographic data from Iowa census

# %%
df = pd.read_csv("/data401/Iowa_Liquor_Sales.csv", iterator=True)

# %%
names = [str(i) for i in range(195)]

# %%
names[1] = "county"
names[3] = "land_area" # in square meters
names[7] = "population"
names[8] = "under_5" # population under 5 years old
names[9] = "5_to_9"
names[10] = "10_to_14"
names[11] = "15_to_19"
names[12] = "20_to_24"
names[13] = "25_to_29"
names[14] = "30_to_34"
names[15] = "35_to_39"
names[16] = "40_to_44"
names[17] = "45_to_49"
names[18] = "50_to_54"
names[19] = "55_to_59"
names[20] = "60_to_64"
names[21] = "65_to_69"
names[22] = "70_to_74"
names[23] = "75_to_79"
names[24] = "80_to_84"
names[25] = "over_84"
names[64] = "median_age"
names[65] = "male_median_age"
names[66] = "female_median_age"
names[73] = "pop_over_21"
names[74] = "male_over_21"
names[75] = "female_over_21"
names[84] = "white" # races (not latinx) should add up to population
names[85] = "black"
names[86] = "american_indian"
names[87] = "asian"
names[95] = "hawaiian_pacific_islander"
names[101] = "other_race"
names[102] = "multiple_races"
names[114] = "latinx"
names[139] = "head_of_household" # population that is a head of their household
names[141] = "has_child" # population that has 1+ children under 18
names[173] = "average_HH_size" # average size of household
names[189] = "owned_housing" # number of housing units that are owned
names[190] = "rented_housing" # number of housing units that are rented

# %%
usecols=[]
for name in names:
    if len(name) > 3:
        usecols.append(name)

# %%
demo = pd.read_csv("census.csv", names=names, usecols=usecols, skiprows=1)
demo = demo[pd.notnull(demo['county'])]
demo["county"]=demo["county"].apply(lambda x: x[:-7].lower())
demo.to_csv('demographics.csv',encoding = "utf8")

# %%
aggdata = pd.read_csv("aggdata.csv")
merged = aggdata.merge(demo, how="left", on="county")

# %%
merged.to_csv('data/aggdata02.csv',encoding = "utf8")

# %% [markdown]
# ## 2. Added DUI data

# %%
agg_iowa = pd.read_csv("data/aggdata02.csv", header=1,
                        names=['date','county','num_purchasers','volume_sold_l','total_retail', 'land_area', 'population', 'under_5', '5_to_9', '10_to_14',
                               '15_to_19', '20_to_24', '25_to_29', '30_to_34', '35_to_39', '40_to_44',
                               '45_to_49', '50_to_54', '55_to_59', '60_to_64', '65_to_69', '70_to_74',
                               '75_to_79', '80_to_84', 'over_84', 'median_age', 'male_median_age',
                               'female_median_age', 'pop_over_21', 'male_over_21', 'female_over_21',
                               'white', 'black', 'american_indian', 'asian',
                               'hawaiian_pacific_islander', 'other_race', 'multiple_races', 'latinx',
                               'head_of_household', 'has_child', 'average_HH_size', 'owned_housing',
                               'rented_housing'])
duis = pd.read_csv('data/dui.csv',header=0,
                  names=['date','county','num_alc_accidents'])

merged = agg_iowa.merge(duis, how='left')

# %%
zerod = merged[merged['date'] <= '2018-06-17'].copy()
averaged = merged[merged['date'] > '2018-06-17'].copy()

# %%
# fill NaN values with 0's for data that we have (up until 2018-06-17)
zerod['num_alc_accidents'] = zerod['num_alc_accidents'].fillna(0)
avg_duis = zerod.groupby('county')['num_alc_accidents'].mean().round()
averaged['num_alc_accidents'] = averaged.apply(lambda row: avg_duis[row['county']], axis=1)

# 19974  1.097236e+09     12534.0    829.0    813.0     826.0
# 19975  1.255598e+09      7570.0    492.0    510.0     476.0
# 19976  1.118443e+09     35625.0   2361.0   2238.0    2131.0
# 19977  1.475845e+09     46225.0   2974.0   3307.0    3655.0
# 19978  1.473276e+09     21704.0   1386.0   1518.0    1585.0
# 19979  1.360875e+09      6403.0    399.0    435.0     391.0
# 19980  1.853444e+09     38013.0   2248.0   2267.0    2359.0
# 19981  1.037262e+09     10866.0    594.0    648.0     677.0
# 19982  1.786750e+09     21056.0   1081.0   1164.0    1226.0
# 19983  2.260630e+09    102172.0   7927.0   7482.0    7281.0
# 19984  1.036315e+09      7598.0    414.0    419.0     554.0
# 19985  1.503287e+09     13229.0    854.0    840.0     848.0
#
#              ...          hawaiian_pacific_islander  other_race  \
# 0            ...                                0.0        22.0
# 1            ...                                1.0       135.0
# 2            ...                                1.0        37.0
# 3            ...                                2.0       239.0
# 4            ...                              201.0      2985.0
# 5            ...                                2.0       231.0
# 6            ...                                1.0       227.0
# 7            ...                              100.0       359.0
# 8            ...                                2.0       111.0
# 9            ...                                1.0        60.0
# 10           ...                                1.0       186.0
# 11           ...                               45.0        86.0
# 12           ...                                3.0       197.0
# 13           ...                                9.0       716.0
# 14           ...                                4.0        89.0
# 15           ...                                1.0       187.0
# 16           ...                               17.0       148.0
# 17           ...                               12.0       899.0
# 18           ...                               16.0       279.0
# 19           ...                               39.0      1009.0
# 20           ...                                0.0        68.0
# 21           ...                               16.0        88.0
# 22           ...                                2.0       115.0
# 23           ...                               21.0       931.0
# 24           ...                                5.0       125.0
# 25           ...                              288.0      1217.0
# 26           ...                                1.0       158.0
# 27           ...                               15.0       193.0
# 28           ...                                4.0       169.0
# 29           ...                                7.0        87.0
# ...          ...                                ...         ...
# 19956        ...                                5.0        99.0
# 19957        ...                               13.0       813.0
# 19958        ...                                NaN         NaN
# 19959        ...                                5.0        50.0
# 19960        ...                                6.0       219.0
# 19961        ...                                6.0        79.0
# 19962        ...                               16.0       250.0
# 19963        ...                               10.0        79.0
# 19964        ...                              254.0     10405.0
# 19965        ...                                NaN         NaN
# 19966        ...                               21.0       259.0
# 19967        ...                                5.0        87.0
# 19968        ...                               68.0      4905.0
# 19969        ...                                2.0        82.0
# 19970        ...                                4.0       314.0
# 19971        ...                               20.0      1518.0
# 19972        ...                                4.0       451.0
# 19973        ...                                3.0        59.0
# 19974        ...                                3.0       125.0
# 19975        ...                                1.0        53.0
# 19976        ...                               48.0       551.0
# 19977        ...                               11.0       562.0
# 19978        ...                               13.0       318.0
# 19979        ...                                1.0        48.0
# 19980        ...                                9.0       681.0
# 19981        ...                                1.0       111.0
# 19982        ...                                4.0       160.0
# 19983        ...                              106.0      3306.0
# 19984        ...                                0.0        67.0
# 19985        ...                                6.0       209.0
#
#        multiple_races   latinx  head_of_household  has_child  average_HH_size  \
# 0                12.0     30.0              963.0      788.0             2.28
# 1                52.0    106.0             2718.0     2603.0             2.27
# 2                 7.0     24.0             1483.0     1254.0             2.29
# 3                69.0    190.0             6138.0     6225.0             2.50
# 4               357.0   3585.0            23861.0    25738.0             2.38
# 5                47.0    161.0             5612.0     5230.0             2.40
# 6                71.0    160.0             4685.0     5212.0             2.53
# 8            12225.0          2400.0                0.0
# 9             7751.0          1681.0                0.0
# 10           16009.0          4340.0                0.0
# 11           10171.0          3481.0                0.0
# 12           14752.0          3423.0                0.0
# 13           32154.0         10839.0                0.0
# 14            6734.0          2400.0                0.0
# 15           12140.0          4293.0                0.0
# 16           14178.0          3664.0                0.0
# 17           36433.0         11831.0                0.0
# 18           12282.0          4229.0                0.0
# 19           53400.0         12219.0                1.0
# 20            7210.0          1419.0                0.0
# 21            5788.0          2006.0                0.0
# 22           14473.0          3073.0                0.0
# 23           29817.0          9823.0                0.0
# 24           13284.0          3172.0                0.0
# 25           69580.0         19805.0                0.0
# 26            7614.0          2148.0                0.0
# 27           15464.0          4634.0                0.0
# 28            8062.0          2420.0                0.0
# 29           10430.0          1869.0                0.0
# ...              ...             ...                ...
# 19956         7760.0          2767.0                0.0
# 19957        32333.0          9859.0                1.0
# 19958            NaN             NaN                0.0
# 19959         5108.0          1242.0                0.0
# 19960        10779.0          3685.0                0.0
# 19961         7046.0          2031.0                0.0
# 19962        19930.0          4707.0                0.0
# 19963         5842.0          1327.0                0.0
# 19964       307321.0        113963.0               12.0
# 19965            NaN             NaN                0.0
# 19966        12912.0          4375.0                0.0
# 19967         8242.0          1885.0                0.0
# 19968       118542.0         43348.0                5.0
# 19969         9515.0          2432.0                0.0
# 19970        26029.0          5265.0                1.0
# 19971        48018.0         33350.0                2.0
# 19972        13781.0          3587.0                0.0
# 19973         4902.0          1319.0                0.0
# 19974         9085.0          3097.0                0.0
# 19975         6228.0          1245.0                0.0
# 19976        26188.0          8570.0                1.0
# 19977        36840.0          7643.0                1.0
# 19978        16723.0          4671.0                0.0
# 19979         5092.0          1220.0                0.0
# 19980        26352.0          9034.0                1.0
# 19981         8075.0          2303.0                0.0
# 19982        15003.0          3765.0                1.0
# 19983        69594.0         29942.0                4.0
# 19984         6172.0          1336.0                0.0
# 19985         9744.0          3287.0                0.0
#
# [19986 rows x 45 columns]

# %%
merged_no_nan.to_csv('data/aggdata03.csv', encoding = "utf8")

# %% [markdown]
# ## 3. Computed variables per capita

# %%
data = pd.read_csv("data/aggdata03.csv", header=0,
                  names=['date','county','num_purchasers','volume_sold_l','total_retail', 'land_area', 'population', 'under_5', '5_to_9', '10_to_14',
                       '15_to_19', '20_to_24', '25_to_29', '30_to_34', '35_to_39', '40_to_44',
                       '45_to_49', '50_to_54', '55_to_59', '60_to_64', '65_to_69', '70_to_74',
                       '75_to_79', '80_to_84', 'over_84', 'median_age', 'male_median_age',
                       'female_median_age', 'pop_over_21', 'male_over_21', 'female_over_21',
                       'white', 'black', 'american_indian', 'asian',
                       'hawaiian_pacific_islander', 'other_race', 'multiple_races', 'latinx',
                       'head_of_household', 'has_child', 'average_HH_size', 'owned_housing',
                       'rented_housing', 'num_alc_accidents'])
# Out:
#          date      county  num_purchasers  volume_sold_l  total_retail  \
# 0  2012-01-08       adams               1         112.94       1491.20
# 1  2012-01-08   appanoose               5         966.80      11837.46
# 2  2012-01-08     audubon               1         235.63       2909.50
# 3  2012-01-08      benton               5         962.46      11928.85
# 4  2012-01-08  black hawk              14        5034.50      71661.42
#
#       land_area  population  under_5  5_to_9  10_to_14        ...          \
# 0  1.096701e+09      4029.0    234.0   209.0     242.0        ...
# 1  1.287981e+09     12887.0    811.0   805.0     767.0        ...
# 2  1.147264e+09      6119.0    335.0   312.0     403.0        ...
# 3  1.855117e+09     26076.0   1645.0  1851.0    1882.0        ...
# 4  1.465334e+09    131090.0   8458.0  7823.0    7550.0        ...
#
#    hawaiian_pacific_islander  other_race  multiple_races  latinx  \
# 0                        0.0        22.0            12.0    30.0
# 1                        1.0       135.0            52.0   106.0
# 2                        1.0        37.0             7.0    24.0
# 3                        2.0       239.0            69.0   190.0
# 4                      201.0      2985.0           357.0  3585.0
#
#    head_of_household  has_child  average_HH_size  owned_housing  \
# 0              963.0      788.0             2.28         3099.0
# 1             2718.0     2603.0             2.27         9562.0
# 2             1483.0     1254.0             2.29         4906.0
# 3             6138.0     6225.0             2.50        21470.0
# 4            23861.0    25738.0             2.38        88103.0
#
#    rented_housing  num_alc_accidents
# 0           816.0                0.0
# 1          3199.0                0.0
# 2          1077.0                0.0
# 3          4293.0                0.0
# 4         37020.0                0.0
#
# [5 rows x 45 columns]

# %%
data['pop_density'] = data['population']/data['land_area']
data['volume_per_cap'] = data['volume_sold_l']/data['population']

# %%
data.to_csv("data/aggdata04.csv")

# %% [markdown]
# ## 4. Feature engineering with demographic variables

# %%
df = pd.read_csv("data/aggdata04.csv")
df.drop([df.columns[0], "female_over_21"], axis=1, inplace=True)

# %%
df["over_65"] = df["65_to_69"] + df["70_to_74"] + df["75_to_79"] + df["80_to_84"] + df["over_84"]

# %%
df.drop(["65_to_69","70_to_74","75_to_79","80_to_84",'60_to_64',"over_84",'5_to_9', '10_to_14','30_to_34', '35_to_39', '40_to_44', '45_to_49',
       '50_to_54', '55_to_59','black', 'american_indian', 'latinx',
       'asian', 'hawaiian_pacific_islander','other_race','multiple_races'], axis=1, inplace=True)

# %%
def make_prop(df, colname):
    newname = colname + "_prop"
    df[newname] = df[colname] / df["population"]
    df.drop(colname, axis=1, inplace=True)

# %%
prop_cols = ['under_5', '15_to_19', '20_to_24', '25_to_29','over_65','pop_over_21', 'male_over_21',
             'white','head_of_household', 'has_child']
for col in prop_cols:
    make_prop(df, col)

# %%
df.to_csv('data/aggdata05.csv',encoding = "utf8")

# %% [markdown]
# ## 5. Added holiday data

# %%
df = pd.read_csv("data/aggdata05.csv", header=0,
                names = ['date', 'county', 'num_purchasers', 'volume_sold_l', 'total_retail',
                       'land_area', 'population', 'median_age', 'male_median_age',
                       'female_median_age', 'average_HH_size', 'owned_housing',
                       'rented_housing', 'num_alc_accidents', 'pop_density', 'volume_per_cap',
                       'under_5_prop', '15_to_19_prop', '20_to_24_prop', '25_to_29_prop',
                       'over_65_prop', 'pop_over_21_prop', 'male_over_21_prop', 'white_prop',
                       'head_of_household_prop', 'has_child_prop'])
cal = calendar()
holidays = cal.holidays(start=min(df['date']), end=max(df['date']))
df["date"] = pd.to_datetime(df["date"])

# %%
def isHoliday(row, holidays):
    span = datetime.timedelta(weeks=2)
    for date in holidays:
        if row['date'] <= date and row['date'] + span >= date:
            return 1
    return 0

# %%
df['isHoliday'] = df.apply(isHoliday, args=(holidays,), axis=1)

# %%
df.to_csv("data/aggdata06.csv",encoding = "utf8")

# %% [markdown]
# ## 6. Conversion to numeric and adding season

# %%
# Read the data

df = pd.read_csv("data/aggdata06.csv")

df.dropna(inplace=True)
df.drop(['Unnamed: 0'], axis=1, inplace=True)

def convert_date(row, start_date):
    return ((row - start_date) / 7).days

# %%
df2 = pd.read_csv('data/aggdata07.csv', header =0,
                 names = ['num_purchasers', 'volume_sold_l', 'total_retail', 'vodka_bottles',
       'tequila_bottles', 'whiskey_bottles', 'rum_bottles', 'gin_bottles',
       'other_bottles', 'avg_bottle_price', 'avg_vendor_size',
       'avg_vendor_vol']).reset_index().drop(['num_purchasers','volume_sold_l','total_retail'], axis=1)
df3 = df.merge(df2, left_on=['date','county'], right_on=['level_0','level_1']).drop(['level_1','level_0'], axis=1).sort_values(by='date')
#df3.to_csv('data/aggdata08.csv', encoding='utf8')

# %%
df3['date'] = pd.to_datetime(df3["date"])
start_date = df3['date'].min()
df3['num_weeks'] = df3['date'].apply(convert_date, args=(start_date,))

# %%
df2[df2['volume_per_cap'] >= 0.678961]
# Out:
#            volume_per_cap
# county
# dickinson        0.678961

# %%
df2.describe()
# Out:
#        vodka_bottles  tequila_bottles  whiskey_bottles   rum_bottles  \
# count   17430.000000     17430.000000     17430.000000  17430.000000
# mean     2480.473379       353.060700      2414.054733   1027.061159
# std      7138.876310      1159.734456      5636.543765   2432.258640
# min         0.000000         0.000000         0.000000      0.000000
# 25%       319.250000        25.000000       455.000000    170.000000
# 50%       641.000000        67.000000       905.500000    337.500000
# 75%      1396.000000       172.000000      1858.750000    742.750000
# max     85900.000000     19571.000000     70268.000000  33849.000000
#
#         gin_bottles  other_bottles  avg_bottle_price  avg_vendor_size  \
# count  17430.000000   17430.000000      17430.000000     17430.000000
# mean     265.090993    1807.153815          1.953057       375.586554
# std      826.669717    4849.067156          0.682012       226.908278
# min        0.000000       0.000000          0.277189         0.000000
# 25%       18.000000     220.000000          1.506227       205.500000
# 50%       46.000000     507.000000          1.833553       326.366667
# 75%      121.000000    1034.000000          2.225082       493.794444
# max    10734.000000   65038.000000          9.188235      2339.400000
#
#        avg_vendor_vol
# count    17430.000000
# mean         0.001350
# std          0.020747
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000

# %%
df2 = df[['volume_per_cap','county']].groupby('county').mean()
df2[df2['volume_per_cap'] < 0.05]
quartile1 = list(df2[df2['volume_per_cap'] <= 0.117975].index)
quartile2 = list(df2[df2['volume_per_cap'] <= 0.179457].index)
quartile3 = list(df2[df2['volume_per_cap'] <= 0.222417].index)
quartile4 = list(df2[df2['volume_per_cap'] < 0.678961].index)

# %%
def cat_county(x):
    if x in quartile1:
        return 'quartile1'
    if x in quartile2:
        return 'quartile2'
    if x in quartile3:
        return 'quartile3'
    if x in quartile4:
        return 'quartile4'
    return 'max'

# %%
df3['county_bin'] = df3['county'].apply(cat_county)

# %%
def seasons(x):
    if x.month in [12,1,2]:
        return 'Winter'
    if x.month in [3,4,5]:
        return 'Spring'
    if x.month in [6,7,8]:
        return 'Summer'
    return 'Fall'

# %%
df3['Seasons'] = df3['date'].apply(seasons)

# %%
df3.drop(['date','county'],axis=1, inplace=True)
df3 = pd.get_dummies(df3, drop_first=True)

# %%
df3.to_csv("data/aggdata08.csv", encoding='utf8')
